# %% [markdown]
# ## Generating a .mp4 file from the results
# Please note that it is important to have the following version of ffmpeg in the `external` folder of PointObject.
# For Windows the ffmpeg binaries must be found in `external\ffmpeg\win64\ffmpeg-20150501-git-02001ad-win64-static\bin\ffmpeg\` and for linux this would be `external/ffmpeg/linux/ffmpeg-2.4.4/ffmpeg/`.

# %%
# %pylab inline
import sys, os
sys.path.insert(1, "/home/berliner/08 GitHub/PointObject")
sys.path.insert(1, "/home/berliner/08 GitHub/PointObject/lib")
from PointObject import PointObject
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Loading a PointObject()
from utils import loadPointObject
mito = loadPointObject('/tmp/my_mito_pointobject.p')
# Out:
# Loading /tmp/my_mito_pointobject.p

# %% [markdown]
# We loaded an PointObject that was already fully analysed. Now we can generate the movie file,
# ```python
#     def saveMovie(fname, plotContour=True, plotCurvature=True, lw=10, alpha=0.8):
#         """
#         Create an .mp4 file showing the progression of the PointObject.
#
#         Requires the ffmpeg binaries to work. It will create a movie file showing
#         the frame-by-frame result as a movie.
#
#         Input:
#           fname (str):           The filename of the movie
#
#           plotContour (bool):    Plot the contour
#
#           plotCurvature (bool):  Color code the contour line based on the local
#                                  curvature.
#
#           lw (int):              Width of the contour line
#
#           alpha (float):         Transparency of the contour line
#
#         """
# ```

# %%
mito.saveMovie('/tmp/MitochondriaMovie', plotContour=True, plotCurvature=True)
